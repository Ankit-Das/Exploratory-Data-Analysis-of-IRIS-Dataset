# %% [markdown]
# #### OBJECTIVE: Suppose we pick a flower from set of three set of flowers:setosa,vercicolor,verginica.We have to determine to which set it belongs based on sepallength,sepalwidth,petallength,petalwidth.
#
# #### Method Used:
# ####     1)Univariate
# ####     2)Bivariate

# %%
# Set the working directory
import os
os.chdir("C:\\Users\\Ankit\\Desktop\\Praxis")

#Read the cars.csv data
import pandas as pd
iris = pd.read_csv("Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
print(iris.shape)
# Out:
# (150, 6)

# %%
print(iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
iris.plot(kind="scatter",
         x="PetalLengthCm",y="PetalWidthCm",
         color=["blue","green","red"],
         figsize=(4,4))

plt.xlabel("Petal_length",fontsize=12)
plt.ylabel("Petal_width",fontsize=12)
plt.title("Scatter Plot",fontsize=12)

plt.show()

# %%
fig, ax = plt.subplots()
ax.set_color_cycle(colors)

# %%
iris['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
groups = iris.groupby('Species')

# Plotp
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.SepalLengthCm, group.SepalWidthCm, marker='o', linestyle='', ms=10, label=name)
#     ax.set_
ax.legend()
#     print(name)
#     break
plt.show()

# %% [markdown]
# Hypothesis:
# Iris-setosa can be easily separated from Iris-versicolor and Iris-verginica by drawing plot between SepalLength and SepalWidth.

# %% [markdown]
# ### Univariate Analysis

# %%
# plt.hist([x, y], bins, label=['x', 'y'])

groups = iris.groupby('Species')

# Plotp
fig, ax = plt.subplots()
for name, group in groups:
    plt.hist([group['PetalLengthCm']])
#     print(name)
ax.legend(name)
#     print(name)
#     break
plt.show()

# %%
groups = iris.groupby('Species')

# Plotp
fig, ax = plt.subplots()
for name, group in groups:
    plt.hist([group['SepalLengthCm']])
#     print(name)
ax.legend(name)
#     print(name)
#     break
plt.show()

# %%
groups = iris.groupby('Species')

# Plotp
fig, ax = plt.subplots()
for name, group in groups:
    plt.hist([group['PetalWidthCm']])
#     print(name)
ax.legend(name)
#     print(name)
#     break
plt.show()

# %%
groups = iris.groupby('Species')

# Plotp
fig, ax = plt.subplots()
for name, group in groups:
    plt.hist([group['SepalWidthCm']])
#     print(name)
ax.legend(name)
#     print(name)
#     break
plt.show()

# %% [markdown]
# Hypothesis(Univariate):
# -Iris-setosa can be easily separated from Iris-versicolor and Iris-verginica by ploting histogram for petal length and petal width.
# -(If-else)condition can be used to separate setosa flower from vercicolor and verginica.
#  for a random flower picked from three set of flowers(Petal length)
#  if PetalLength<2:
#      print(setosa)
#  if PetalLength>3&&PetalLength<4.6:
#      print(vercicolor)
#  if PetalLength>4.6&&PetalLength<6.8:
#      print(vercicolor)
#
#  for a random flower from three set of flowers(Petal Width)
#  if PetalLength<0.6:
#      print(setosa)
#  if PetalLength>1&&PetalLength<1.5:
#      print(vercicolor)
#  if PetalLength>1.5&&PetalLength<2.5:
#      print(vercicolor)

# %% [markdown]
# ### Bivariate Analysis

# %%
import seaborn as sns
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris, hue="Species", size=3);
plt.show()

# %% [markdown]
# Hypothesis:
# -petal_length and petal_width are the most useful features to identify various flower types.
# -While Setosa can be easily identified, Virnica and Versicolor have some overlap.
# -(if-else) conditions can be used on petal_length and petal_width to classify various flower type.
#   if PetalLength<2&& PetalWidth<=1:
#   print(setosa)
#   elif PetalLength>2.5&& PetalLength<5&PetalWidth>=1&& PetalWidth<=2:
#   print(vercicolor)
#   else:
#   print(verginica)

# %% [markdown]
# ### Univariate Analysis (Box-plot)

# %%
iris.boxplot(column="PetalLengthCm",by="Species")
plt.show()

# %%
Hypothesis:
    -All the points for setosa flower lie in the range of 0 to 2(petal length).
    -Points in the range of 4.5 to 5 overlaps for vercicolor and verginica.
     We cannot declare this points as vercicolor or verginica.
